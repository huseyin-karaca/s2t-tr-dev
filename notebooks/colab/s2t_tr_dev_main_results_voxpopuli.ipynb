# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyin-karaca/s2t-tr-dev/blob/main/notebooks/colab/s2t_tr_dev_main_results_voxpopuli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huseyin-karaca/s2t-tr-dev
# %cd /content/s2t-tr-dev
# Out:
# Cloning into 's2t-tr-dev'...
# remote: Enumerating objects: 659, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (265/265), done.
# remote: Total 659 (delta 226), reused 312 (delta 129), pack-reused 244 (from 2)
# Receiving objects: 100% (659/659), 738.91 MiB | 33.39 MiB/s, done.
# Resolving deltas: 100% (312/312), done.
# Updating files: 100% (190/190), done.
# /content/s2t-tr-dev

# %%
from google.colab import files
files.view('/content/s2t-tr-dev')

# %%
# !make create_environment
# !make requirements
# Out:
# uv venv --python 3.10
# ...
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# >>> New uv virtual environment created. Activate with:
# >>> Windows: .\.venv\Scripts\activate
# >>> Unix/macOS: source ./.venv/bin/activate
# uv sync
# Resolved 214 packages in 9ms
# Prepared 210 packages in 16.17s
# Installed 210 packages in 429ms
#  + absl-py==2.4.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.13.0
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.3.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + audioread==3.1.0
#  + babel==2.18.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + certifi==2026.2.25
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + click==8.3.2
#  + comm==0.2.3
# ...

# %%
from google.colab import userdata
import os
os.environ['GITHUB_TOKEN'] = userdata.get('GitHubPAT')
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# W&B kimlik doğrulaması için eklendi
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')

# !gh auth status
# !git config --global user.name 'huseyin-karaca'
# !git config --global user.email 'huseyinkaraccca@gmail.com'
# Out:
# github.com
#   ✓ Logged in to github.com account huseyin-karaca (GITHUB_TOKEN)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AUNXCOA01Derj8bnLEVE_***********************************************************

# %%
# !mkdir -p data/processed/facebook_voxpopuli
# !mkdir -p data/interim/facebook_voxpopuli

# w2v2 large robust https://drive.google.com/file/d/1XixN6PyWOLJNqRTraTeq28otdxdrdH07/view?usp=sharing
# hubert https://drive.google.com/file/d/1dlidbh8QzlPRQU5tNSSp4OolqKRFgkc5/view?usp=sharing
# openai_whisper-base https://drive.google.com/file/d/1jRcQAQl6VZGiZeg24aiven2KwKooAdPN/view?usp=sharing
# !gdown 1XixN6PyWOLJNqRTraTeq28otdxdrdH07 -O data/interim/facebook_voxpopuli/facebook_wav2vec2-large-robust-ft-swbd-300h.parquet
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XixN6PyWOLJNqRTraTeq28otdxdrdH07
# From (redirected): https://drive.google.com/uc?id=1XixN6PyWOLJNqRTraTeq28otdxdrdH07&confirm=t&uuid=380d0f2f-23ce-474a-9f37-a74447c2d527
# To: /content/s2t-tr-dev/data/interim/facebook_voxpopuli/facebook_wav2vec2-large-robust-ft-swbd-300h.parquet
# 100% 9.78G/9.78G [01:11<00:00, 137MB/s]

# %%
# !make download_voxpopuli
# Out:
# uv run python -m src.data.get_processed -d voxpopuli
# 2026-04-30 12:58:51.667 | INFO     | __main__:fetch:51 - Downloading processed VOXPOPULI dataset to data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet...
# Downloading...
# From (original): https://drive.google.com/uc?id=1yf-G-DWhhZLlqeGXZ77GbuhTBmhqyyXA
# From (redirected): https://drive.google.com/uc?id=1yf-G-DWhhZLlqeGXZ77GbuhTBmhqyyXA&confirm=t&uuid=aa44a36c-6fbf-473e-a55c-50bfd373c6ec
# To: /content/s2t-tr-dev/data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet
# 100% 24.2G/24.2G [02:39<00:00, 152MB/s]
# 2026-04-30 13:01:33.058 | INFO     | __main__:fetch:57 - Download completed successfully: data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet

# %%
# !uv run python -m src.experiments.main_results experiments=main_results_voxpopuli_v2
# Out:
# [2026-04-30 10:37:32,125][__main__][INFO] - >>> training-free baselines
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.eval_baselines --parquet-path data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet --split test --save-json reports/baselines.json --train-ratio 0.8 --val-ratio 0.1
# 2026-04-30 10:37:33,080 [INFO] __main__: Loaded WER matrix from data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet — N=8374, K=3, splits: train=6699 val=837 test=838
# 2026-04-30 10:37:33,081 [INFO] __main__: === Baselines on test split ===
# 2026-04-30 10:37:33,081 [INFO] __main__:   single_hubert          wer=0.2316 ± 0.0057 (n=838)
# 2026-04-30 10:37:33,081 [INFO] __main__:   single_whisper         wer=1.2140 ± 0.1342 (n=838)
# 2026-04-30 10:37:33,081 [INFO] __main__:   single_wav2vec2        wer=0.2981 ± 0.0069 (n=838)
# 2026-04-30 10:37:33,081 [INFO] __main__:   oracle                 wer=0.1647 ± 0.0048 (n=838)
# ...

# %%
# !uv run python -m src.experiments.main_results experiments=main_results_voxpopuli_v3
# Out:
# [2026-04-30 13:10:55,226][__main__][INFO] - >>> training-free baselines
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.eval_baselines --parquet-path data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet --split test --save-json reports/baselines.json --train-ratio 0.8 --val-ratio 0.1
# 2026-04-30 13:10:56,138 [INFO] __main__: Loaded WER matrix from data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet — N=8374, K=3, splits: train=6699 val=837 test=838
# 2026-04-30 13:10:56,139 [INFO] __main__: === Baselines on test split ===
# 2026-04-30 13:10:56,139 [INFO] __main__:   single_hubert          wer=0.2316 ± 0.0057 (n=838)
# 2026-04-30 13:10:56,139 [INFO] __main__:   single_whisper         wer=1.2140 ± 0.1342 (n=838)
# 2026-04-30 13:10:56,139 [INFO] __main__:   single_wav2vec2        wer=0.2981 ± 0.0069 (n=838)
# 2026-04-30 13:10:56,139 [INFO] __main__:   oracle                 wer=0.1647 ± 0.0048 (n=838)
# ...

# %%
# !git stash
# !git pull
# Out:
# Saved working directory and index state WIP on main: ca95a2a feat: add new Makefile targets for running main results pipelines for VoxPopuli datasets V2 and V3, and comment out PROJ_ROOT logging in config.py
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (3/3), done.
# Unpacking objects: 100% (10/10), 1.92 KiB | 1.92 MiB/s, done.
# remote: Total 10 (delta 7), reused 10 (delta 7), pack-reused 0 (from 0)
# From https://github.com/huseyin-karaca/s2t-tr-dev
#    ca95a2a..cddde7f  main       -> origin/main
# Updating ca95a2a..cddde7f
# Fast-forward
#  Makefile                                           |  5 ++++
#  configs/experiments/main_results_voxpopuli_v3.yaml |  2 +-
#  configs/experiments/main_results_voxpopuli_v4.yaml | 35 ++++++++++++++++++++++
#  src/training/train.py                              | 23 +++++++++++---
#  4 files changed, 60 insertions(+), 5 deletions(-)
# ...

# %%
# !make run_main_results_voxpopuli_v4
# Out:
# uv run python -m src.experiments.main_results experiments=main_results_voxpopuli_v4
# [2026-04-30 13:49:55,362][__main__][INFO] - >>> training-free baselines
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.eval_baselines --parquet-path data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet --split test --save-json reports/baselines.json --train-ratio 0.8 --val-ratio 0.1
# 2026-04-30 13:49:56,281 [INFO] __main__: Loaded WER matrix from data/processed/facebook_voxpopuli/combined_features_with_transcripts.parquet — N=8374, K=3, splits: train=6699 val=837 test=838
# 2026-04-30 13:49:56,282 [INFO] __main__: === Baselines on test split ===
# 2026-04-30 13:49:56,282 [INFO] __main__:   single_hubert          wer=0.2316 ± 0.0057 (n=838)
# 2026-04-30 13:49:56,282 [INFO] __main__:   single_whisper         wer=1.2140 ± 0.1342 (n=838)
# 2026-04-30 13:49:56,282 [INFO] __main__:   single_wav2vec2        wer=0.2981 ± 0.0069 (n=838)
# ...

# %%
from google.colab import runtime
runtime.unassign()
