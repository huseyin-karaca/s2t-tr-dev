# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyin-karaca/s2t-tr-dev/blob/main/s2t_tr_dev_main_results_ami.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huseyin-karaca/s2t-tr-dev
# %cd /content/s2t-tr-dev
# Out:
# Cloning into 's2t-tr-dev'...
# remote: Enumerating objects: 617, done.
# remote: Counting objects: 100% (373/373), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 617 (delta 198), reused 277 (delta 110), pack-reused 244 (from 2)
# Receiving objects: 100% (617/617), 738.90 MiB | 49.44 MiB/s, done.
# Resolving deltas: 100% (284/284), done.
# Updating files: 100% (185/185), done.
# /content/s2t-tr-dev

# %%
from google.colab import files
files.view('/content/s2t-tr-dev')

# %%
# !make create_environment
# !make requirements
# Out:
# uv venv --python 3.10
# ...
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# >>> New uv virtual environment created. Activate with:
# >>> Windows: .\.venv\Scripts\activate
# >>> Unix/macOS: source ./.venv/bin/activate
# uv sync
# Resolved 214 packages in 9ms
# Prepared 210 packages in 23.03s
# Installed 210 packages in 175ms
#  + absl-py==2.4.0
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.13.0
#  + argon2-cffi==25.1.0
#  + argon2-cffi-bindings==25.1.0
#  + arrow==1.4.0
#  + asttokens==3.0.1
#  + async-lru==2.3.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + audioread==3.1.0
#  + babel==2.18.0
#  + beautifulsoup4==4.14.3
#  + bleach==6.3.0
#  + certifi==2026.2.25
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + click==8.3.2
#  + comm==0.2.3
# ...

# %%
from google.colab import userdata
import os
os.environ['GITHUB_TOKEN'] = userdata.get('GitHubPAT')
os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# W&B kimlik doğrulaması için eklendi
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')

# !gh auth status
# !git config --global user.name 'huseyin-karaca'
# !git config --global user.email 'huseyinkaraccca@gmail.com'
# Out:
# github.com
#   ✓ Logged in to github.com account huseyin-karaca (GITHUB_TOKEN)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: github_pat_11AUNXCOA01Derj8bnLEVE_***********************************************************

# %%
# !make download_ami
# Out:
# uv run python -m src.data.get_processed -d ami
# 2026-04-29 20:26:20.223 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# 2026-04-29 20:26:20.454 | INFO     | __main__:fetch:47 - Downloading processed AMI dataset to data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet...
# Downloading...
# From (original): https://drive.google.com/uc?id=1FgN4FQ422HPDCwG-Wl4jrXQGl0tgX6ZP
# From (redirected): https://drive.google.com/uc?id=1FgN4FQ422HPDCwG-Wl4jrXQGl0tgX6ZP&confirm=t&uuid=8ab05640-3a34-4c6f-b5c0-14aa6d73fdba
# To: /content/s2t-tr-dev/data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet
# 100% 7.96G/7.96G [01:37<00:00, 82.1MB/s]
# 2026-04-29 20:27:59.485 | INFO     | __main__:fetch:53 - Download completed successfully: data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet

# %%
# !make run_main_results_ami
# Out:
# uv run python -m src.experiments.main_results experiments=main_results_ami
# 2026-04-29 20:27:59.612 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# [2026-04-29 20:28:00,018][__main__][INFO] - >>> training-free baselines
#     /content/s2t-tr-dev/.venv/bin/python3 -m src.training.eval_baselines --parquet-path data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet --split test --save-json reports/baselines.json --train-ratio 0.8 --val-ratio 0.1
# 2026-04-29 20:28:00.061 | INFO     | src.config:<module>:9 - PROJ_ROOT path is: /content/s2t-tr-dev
# 2026-04-29 20:28:02,038 [INFO] __main__: Loaded WER matrix from data/processed/edinburghcstr_ami/combined_features_with_transcripts.parquet — N=12612, K=3, splits: train=10089 val=1261 test=1262
# 2026-04-29 20:28:02,039 [INFO] __main__: === Baselines on test split ===
# 2026-04-29 20:28:02,039 [INFO] __main__:   single_hubert          wer=0.6347 ± 0.0145 (n=1262)
# ...

# %%
# !uv run python -m src.experiments.main_results experiments=main_results_ami \
  experiments.methods.0.seed=[1337,31415,11235,12321,27182,1618,10101,7777,86400,98765,34567,42069,2026] \
  experiments.methods.1.seed=[1337,31415,11235,12321,27182,1618,10101,7777,86400,98765,34567,42069,2026]
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 8: 100% 78/78 [00:13<00:00,  5.73it/s, v_num=duf2, train/total_loss_step=0.873, train/selected_wer_step=0.277, train/selection_accuracy_step=0.602, val/total_loss=0.882, val/selected_wer=0.518, val/selection_accuracy=0.615, train/total_loss_epoch=0.858, train/selected_wer_epoch=0.379, train/selection_accuracy_epoch=0.630]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/10 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 10/10 [00:01<00:00,  7.06it/s]
# ...

# %%
from google.colab import runtime
runtime.unassign()
